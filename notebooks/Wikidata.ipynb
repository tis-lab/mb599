# %%
import json
from pprint import pprint
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %%
def generate_query():
    wd_query = '''
        SELECT DISTINCT ?exposureLabel ?chemicalLabel 
        # ?chebi ?symptomLabel 
        # ?exposure_routeLabel ?reference_URL WHERE {
        # ?exposure wdt:P279 wd:Q21167512;
                    wdt:P828 ?chemical;
                    wdt:P780 ?symptom;
                    wdt:P636 ?exposure_route.
          # ?chemical wdt:P683 ?chebi.
          # ?exposure p:P636 ?exposure_statement.
          # ?exposure_statement prov:wasDerivedFrom/pr:P854 ?reference_URL.

          SERVICE wikibase:label { bd:serviceParam wikibase:language "en" . }
        } 
        ''' 
    return wd_query

def query_wikidata(query):
    wd_endpoint = 'https://query.wikidata.org/sparql'
    return execute_query(endpoint=wd_endpoint, query=query)

def execute_query(endpoint, query):
    endpoint = SPARQLWrapper(endpoint)
    endpoint.setQuery(query)
    endpoint.setReturnFormat(JSON)
    return endpoint.query().convert()['results']['bindings']

def parse_object(obj):  
    return {
         'chebi': obj['chebi']['value'],
         'chemicalLabel': obj['chemicalLabel']['value'],
         'exposure_routeLabel': obj['exposure_routeLabel']['value'],
         'reference_URL': obj['reference_URL']['value'],
         'symptomLabel': obj['symptomLabel']['value']
    }

# %%
query1 = generate_query()
q1r = query_wikidata(query1)
results = []
for obj in q1r:
    results.append(parse_object(obj))

# %%
csv_df = pd.DataFrame(data=results)

# %%
csv_df.to_csv('wikidata_exposure_symptoms.csv', sep='\t')

# %%
ecto_lookup = dict()
with open('../data/ecto.json', 'r') as ecto:
    ecto = json.load(ecto)
    graphs = ecto['graphs']
    for graph in graphs:
        for index, node in enumerate(graph['nodes']):
            if 'lbl' in node.keys() and 'ECTO' in node['id']:
                ecto_lookup[node['lbl']] = node['id']
pprint(ecto_lookup)
# Out:
# {'abdominal radiography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001121',
#  'activity related exposure': 'http://purl.obolibrary.org/obo/ECTO_0002032',
#  'alcohol abuse related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001095',
#  'alcohol consumption related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001082',
#  'asbestos mining related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001154',
#  'axotomy of saphenous nerve': 'http://purl.obolibrary.org/obo/ECTO_0002044',
#  'axotomy of sciatic nerve': 'http://purl.obolibrary.org/obo/ECTO_0002045',
#  'behavior related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001974',
#  'bronchography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001118',
#  'chest radiography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001122',
#  'cholangiography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001123',
#  'cigar smoking related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001092',
#  'cigarette smoking related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001091',
#  'clinical or research activity related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001109',
#  'cooking practices related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001104',
#  'coping skills related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001080',
#  'cystography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001119',
#  'diagnostic imaging related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001110',
#  'dietary aflatoxin exposure': 'http://purl.obolibrary.org/obo/ECTO_0002396',
#  'dietary antimony exposure': 'http://purl.obolibrary.org/obo/ECTO_0002397',
#  'dietary arsenic exposure': 'http://purl.obolibrary.org/obo/ECTO_0002398',
#  'dietary bisphenol A exposure': 'http://purl.obolibrary.org/obo/ECTO_0002401',
#  'dietary cadmium exposure': 'http://purl.obolibrary.org/obo/ECTO_0002399',
#  'dietary chemical entity exposure': 'http://purl.obolibrary.org/obo/ECTO_0002395',
#  "dietary disodium 5'-guanylate exposure": 'http://purl.obolibrary.org/obo/ECTO_0002403',
#  'dietary flavouring agent exposure': 'http://purl.obolibrary.org/obo/ECTO_0002393',
#  'dietary food additive exposure': 'http://purl.obolibrary.org/obo/ECTO_0002389',
#  'dietary food colouring exposure': 'http://purl.obolibrary.org/obo/ECTO_0002392',
#  'dietary food emulsifier exposure': 'http://purl.obolibrary.org/obo/ECTO_0002394',
#  'dietary food preservative exposure': 'http://purl.obolibrary.org/obo/ECTO_0002391',
#  'dietary mercury exposure': 'http://purl.obolibrary.org/obo/ECTO_0002400',
#  'dietary monosodium glutamate exposure': 'http://purl.obolibrary.org/obo/ECTO_0002402',
#  'dietary practices related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001098',
#  'dietary sweetening agent exposure': 'http://purl.obolibrary.org/obo/ECTO_0002390',
#  'drug abuse related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001094',
#  'exposure to (+)-trans-allethrin': 'http://purl.obolibrary.org/obo/ECTO_0001603',
#  'exposure to (-)-ephedrine': 'http://purl.obolibrary.org/obo/ECTO_0001166',
#  'exposure to (2,4,5-trichlorophenoxy)acetic acid': 'http://purl.obolibrary.org/obo/ECTO_0002257',
#  'exposure to (2,4-dichlorophenoxy)acetate': 'http://purl.obolibrary.org/obo/ECTO_0001691',
#  'exposure to (4-chloro-2-methylphenoxy)acetic acid': 'http://purl.obolibrary.org/obo/ECTO_0001349',
#  'exposure to (E)-1,3-dichloropropene': 'http://purl.obolibrary.org/obo/ECTO_0001709',
#  'exposure to (E)-acetamiprid': 'http://purl.obolibrary.org/obo/ECTO_0001299',
#  'exposure to (E)-clothianidin': 'http://purl.obolibrary.org/obo/ECTO_0001305',
#  'exposure to (E)-imidacloprid': 'http://purl.obolibrary.org/obo/ECTO_0001301',
#  'exposure to (E)-roxithromycin': 'http://purl.obolibrary.org/obo/ECTO_0001344',
#  'exposure to (E)-thiamethoxam': 'http://purl.obolibrary.org/obo/ECTO_0001308',
#  'exposure to (R)-(+)-propranolol': 'http://purl.obolibrary.org/obo/ECTO_0001505',
#  'exposure to (R)-amphetamine': 'http://purl.obolibrary.org/obo/ECTO_0001321',
#  'exposure to (R)-atenolol': 'http://purl.obolibrary.org/obo/ECTO_0001357',
#  'exposure to (R)-bupropion': 'http://purl.obolibrary.org/obo/ECTO_0001275',
#  'exposure to (R)-ketamine': 'http://purl.obolibrary.org/obo/ECTO_0001360',
#  'exposure to (R)-salbutamol': 'http://purl.obolibrary.org/obo/ECTO_0001506',
#  'exposure to (RS)-amphetamine': 'http://purl.obolibrary.org/obo/ECTO_0001354',
#  'exposure to (S)-amphetamine': 'http://purl.obolibrary.org/obo/ECTO_0001326',
#  'exposure to (S)-bupropion': 'http://purl.obolibrary.org/obo/ECTO_0001274',
#  'exposure to (Z)-acetamiprid': 'http://purl.obolibrary.org/obo/ECTO_0001300',
#  'exposure to (Z)-imidacloprid': 'http://purl.obolibrary.org/obo/ECTO_0001302',
#  'exposure to (Z)-thiacloprid': 'http://purl.obolibrary.org/obo/ECTO_0001304',
#  'exposure to (trifluoromethyl)benzene': 'http://purl.obolibrary.org/obo/ECTO_0001276',
#  "exposure to 1,1'-azobis(N,N-dimethylformamide)": 'http://purl.obolibrary.org/obo/ECTO_0000304',
#  'exposure to 1,1,1,2-tetrachloroethane': 'http://purl.obolibrary.org/obo/ECTO_0001902',
#  'exposure to 1,1,1-trichloroethane': 'http://purl.obolibrary.org/obo/ECTO_0001533',
#  'exposure to 1,1,2,2-tetrachloroethane': 'http://purl.obolibrary.org/obo/ECTO_0001534',
#  'exposure to 1,1,2-trichloroethane': 'http://purl.obolibrary.org/obo/ECTO_0001535',
#  'exposure to 1,1-Dichloroethane': 'http://purl.obolibrary.org/obo/ECTO_0001536',
#  'exposure to 1,1-dichloroethene': 'http://purl.obolibrary.org/obo/ECTO_0001537',
#  'exposure to 1,1-dimethylhydrazine': 'http://purl.obolibrary.org/obo/ECTO_0002291',
#  'exposure to 1,2,3,4,6,7,8-Heptachlorodibenzodioxin': 'http://purl.obolibrary.org/obo/ECTO_0001971',
#  'exposure to 1,2,3,4,6,7,8-Heptachlorodibenzofuran': 'http://purl.obolibrary.org/obo/ECTO_0001973',
#  'exposure to 1,2,3,4,7,8-Hexachlorodibenzodioxin': 'http://purl.obolibrary.org/obo/ECTO_0001969',
#  'exposure to 1,2,3,6,7,8-Hexachlorodibenzodioxin': 'http://purl.obolibrary.org/obo/ECTO_0001970',
#  'exposure to 1,2,3-Trichloropropane': 'http://purl.obolibrary.org/obo/ECTO_0001926',
#  'exposure to 1,2,3-trimethylbenzene': 'http://purl.obolibrary.org/obo/ECTO_0002269',
#  'exposure to 1,2,4-trichlorobenzene': 'http://purl.obolibrary.org/obo/ECTO_0001923',
#  'exposure to 1,2,4-trimethylbenzene': 'http://purl.obolibrary.org/obo/ECTO_0001929',
#  'exposure to 1,2-Dibromo-3-chloropropane': 'http://purl.obolibrary.org/obo/ECTO_0001538',
#  'exposure to 1,2-Dichloropropane': 'http://purl.obolibrary.org/obo/ECTO_0001543',
#  'exposure to 1,2-dibromoethane': 'http://purl.obolibrary.org/obo/ECTO_0001699',
#  'exposure to 1,2-dichlorobenzene': 'http://purl.obolibrary.org/obo/ECTO_0001539',
#  'exposure to 1,2-dichloroethane': 'http://purl.obolibrary.org/obo/ECTO_0001138',
#  'exposure to 1,2-dichloroethene': 'http://purl.obolibrary.org/obo/ECTO_0001706',
#  'exposure to 1,2-dimethylhydrazine': 'http://purl.obolibrary.org/obo/ECTO_0002024',
#  'exposure to 1,2-dinitrobenzene': 'http://purl.obolibrary.org/obo/ECTO_0001730',
#  'exposure to 1,2-epoxypropane': 'http://purl.obolibrary.org/obo/ECTO_0001882',
#  'exposure to 1,2-phenylenediamine': 'http://purl.obolibrary.org/obo/ECTO_0001858',
#  'exposure to 1,3,5-trimethylbenzene': 'http://purl.obolibrary.org/obo/ECTO_0002270',
#  'exposure to 1,3,5-trinitro-1,3,5-triazinane': 'http://purl.obolibrary.org/obo/ECTO_0002121',
#  'exposure to 1,3-Propane sultone': 'http://purl.obolibrary.org/obo/ECTO_0002369',
#  'exposure to 1,3-benzothiazole-2-thiol': 'http://purl.obolibrary.org/obo/ECTO_0001792',
#  'exposure to 1,3-dichlorobenzene': 'http://purl.obolibrary.org/obo/ECTO_0001701',
#  'exposure to 1,3-dichloropropane': 'http://purl.obolibrary.org/obo/ECTO_0002412',
#  'exposure to 1,3-dichloropropene': 'http://purl.obolibrary.org/obo/ECTO_0002292',
#  'exposure to 1,3-dinitrobenzene': 'http://purl.obolibrary.org/obo/ECTO_0001729',
#  'exposure to 1,3-phenylenediamine': 'http://purl.obolibrary.org/obo/ECTO_0001859',
#  'exposure to 1,4 dioxin': 'http://purl.obolibrary.org/obo/ECTO_0002305',
#  'exposure to 1,4-dichlorobenzene': 'http://purl.obolibrary.org/obo/ECTO_0001702',
#  'exposure to 1,4-dinitrobenzene': 'http://purl.obolibrary.org/obo/ECTO_0001731',
#  'exposure to 1,4-dioxane': 'http://purl.obolibrary.org/obo/ECTO_0001738',
#  'exposure to 1,4-diphenylbenzene': 'http://purl.obolibrary.org/obo/ECTO_0002259',
#  'exposure to 1,4-dithiothreitol': 'http://purl.obolibrary.org/obo/ECTO_0000297',
#  'exposure to 1,4-phenylenediamine': 'http://purl.obolibrary.org/obo/ECTO_0001860',
#  'exposure to 1,5-Naphthalene diisocyanate': 'http://purl.obolibrary.org/obo/ECTO_0001968',
#  'exposure to 1,6-Dinitropyrene': 'http://purl.obolibrary.org/obo/ECTO_0001959',
#  'exposure to 1,8-Dinitropyrene': 'http://purl.obolibrary.org/obo/ECTO_0001960',
#  'exposure to 1-(3,5-dichloro-2,6-dihydroxy-4-methoxyphenyl)hexan-1-one': 'http://purl.obolibrary.org/obo/ECTO_0000398',
#  'exposure to 1-(3-(trifluoromethyl)phenyl)piperazine': 'http://purl.obolibrary.org/obo/ECTO_0001489',
#  'exposure to 1-(3-chlorophenyl)piperazine': 'http://purl.obolibrary.org/obo/ECTO_0001159',
#  'exposure to 1-Amino-2,4-dibromoanthraquinone': 'http://purl.obolibrary.org/obo/ECTO_0001613',
#  'exposure to 1-Amino-2-methylanthraquinone': 'http://purl.obolibrary.org/obo/ECTO_0001612',
#  'exposure to 1-aminocyclopropanecarboxylic acid': 'http://purl.obolibrary.org/obo/ECTO_0000134',
#  'exposure to 1-benzylpiperazine': 'http://purl.obolibrary.org/obo/ECTO_0001490',
#  "exposure to 1-chloro-2,2-bis(4'-chlorophenyl)ethylene": 'http://purl.obolibrary.org/obo/ECTO_0001188',
#  'exposure to 1-dodecylguanidine': 'http://purl.obolibrary.org/obo/ECTO_0001742',
#  'exposure to 1-methyl-4-phenyl-1,2,3,6-tetrahydropyridine': 'http://purl.obolibrary.org/obo/ECTO_0001982',
#  'exposure to 1-naphthylamine': 'http://purl.obolibrary.org/obo/ECTO_0001815',
#  'exposure to 1-nitronaphthalene': 'http://purl.obolibrary.org/obo/ECTO_0001223',
#  'exposure to 1-nitropropane': 'http://purl.obolibrary.org/obo/ECTO_0002362',
#  'exposure to 1-nitropyrene': 'http://purl.obolibrary.org/obo/ECTO_0001963',
#  'exposure to 1-oleoyl-sn-glycerol 3-phosphate': 'http://purl.obolibrary.org/obo/ECTO_0000447',
#  'exposure to 10H-phenothiazine': 'http://purl.obolibrary.org/obo/ECTO_0002228',
#  'exposure to 11-deoxycorticosterone': 'http://purl.obolibrary.org/obo/ECTO_0000408',
#  'exposure to 17alpha-ethynylestradiol': 'http://purl.obolibrary.org/obo/ECTO_0000443',
#  'exposure to 1H-indene': 'http://purl.obolibrary.org/obo/ECTO_0002176',
#  'exposure to 1H-pyrazole': 'http://purl.obolibrary.org/obo/ECTO_0001981',
#  "exposure to 2,2',3,3',5,5'-hexachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001224',
#  "exposure to 2,2',3,3',6,6'-hexachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001225',
#  "exposure to 2,2',3,4,4',5',6-Heptabromodiphenyl ether": 'http://purl.obolibrary.org/obo/ECTO_0001551',
#  "exposure to 2,2',4,4',5,5'-Hexabromodiphenyl ether": 'http://purl.obolibrary.org/obo/ECTO_0001549',
#  "exposure to 2,2',4,4',5,5'-hexabromobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0002423',
#  "exposure to 2,2',4,4',5,5'-hexachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001226',
#  "exposure to 2,2',4,4',5,6'-Hexabromodiphenyl ether": 'http://purl.obolibrary.org/obo/ECTO_0001550',
#  "exposure to 2,2',4,4',5-Pentabromodiphenyl ether": 'http://purl.obolibrary.org/obo/ECTO_0001548',
#  "exposure to 2,2',4,4',6,6'-hexachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001227',
#  "exposure to 2,2',4,4'-Tetrabromodiphenyl ether": 'http://purl.obolibrary.org/obo/ECTO_0001547',
#  "exposure to 2,2',4,4'-tetrachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001228',
#  "exposure to 2,2',4,5-tetrachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001229',
#  "exposure to 2,2',5,5'-tetrachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001230',
#  "exposure to 2,3',4,4',5'-Pentachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001421',
#  "exposure to 2,3',4,4',5,5'-Hexachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001424',
#  "exposure to 2,3',4,4',5-Pentachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001420',
#  "exposure to 2,3',5-trichlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001231',
#  "exposure to 2,3,3',4,4',5'-Hexachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001423',
#  "exposure to 2,3,3',4,4',5,5'-Heptachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001425',
#  "exposure to 2,3,3',4,4',5-Hexachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001422',
#  "exposure to 2,3,3',4,5-pentachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001232',
#  "exposure to 2,3,4,3',4'-Pentachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001418',
#  "exposure to 2,3,4,4',5-Pentachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001419',
#  "exposure to 2,3,4,4'-tetrachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001233',
#  'exposure to 2,3,4,5,6-pentachlorobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001234',
#  'exposure to 2,3,4,5-tetrachlorobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001235',
#  'exposure to 2,3,4-trichlorobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001236',
#  'exposure to 2,3,5,6-tetrachlorobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001237',
#  'exposure to 2,3,5-trimethylphenyl methylcarbamate': 'http://purl.obolibrary.org/obo/ECTO_0001930',
#  'exposure to 2,3,6-trichlorobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001238',
#  'exposure to 2,3,7,8-Tetrachlorodibenzofuran': 'http://purl.obolibrary.org/obo/ECTO_0001972',
#  'exposure to 2,3,7,8-tetrachlorodibenzodioxine': 'http://purl.obolibrary.org/obo/ECTO_0000456',
#  "exposure to 2,4'-dichlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001239',
#  "exposure to 2,4,4',6-tetrachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001240',
#  'exposure to 2,4,5-trichlorophenol': 'http://purl.obolibrary.org/obo/ECTO_0001924',
#  'exposure to 2,4,6-tribromophenol': 'http://purl.obolibrary.org/obo/ECTO_0001336',
#  'exposure to 2,4,6-trichlorophenol': 'http://purl.obolibrary.org/obo/ECTO_0001925',
#  'exposure to 2,4,6-trinitrotoluene': 'http://purl.obolibrary.org/obo/ECTO_0002383',
#  'exposure to 2,4-D': 'http://purl.obolibrary.org/obo/ECTO_0001198',
#  'exposure to 2,4-DB': 'http://purl.obolibrary.org/obo/ECTO_0001693',
#  'exposure to 2,4-Diaminoanisole': 'http://purl.obolibrary.org/obo/ECTO_0001695',
#  'exposure to 2,4-Dimethylphenol': 'http://purl.obolibrary.org/obo/ECTO_0001726',
#  'exposure to 2,4-diaminotoluene': 'http://purl.obolibrary.org/obo/ECTO_0001696',
#  'exposure to 2,4-dibromophenyl 2,3,4-tribromophenyl ether': 'http://purl.obolibrary.org/obo/ECTO_0002421',
#  'exposure to 2,4-dibromophenyl 2,4,6-tribromophenyl ether': 'http://purl.obolibrary.org/obo/ECTO_0002422',
#  'exposure to 2,4-dibromophenyl 3,4-dibromophenyl ether': 'http://purl.obolibrary.org/obo/ECTO_0002420',
#  'exposure to 2,4-dichlorophenol': 'http://purl.obolibrary.org/obo/ECTO_0001708',
#  'exposure to 2,4-dinitrophenol': 'http://purl.obolibrary.org/obo/ECTO_0001733',
#  'exposure to 2,4-dinitrotoluene': 'http://purl.obolibrary.org/obo/ECTO_0001734',
#  'exposure to 2,5-Dimethylfuran': 'http://purl.obolibrary.org/obo/ECTO_0001544',
#  'exposure to 2,5-dichlorobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001241',
#  'exposure to 2,6-di-tert-butyl-4-methylphenol': 'http://purl.obolibrary.org/obo/ECTO_0002141',
#  'exposure to 2,6-dichloro-4-nitroaniline': 'http://purl.obolibrary.org/obo/ECTO_0001700',
#  'exposure to 2,6-dichlorobenzonitrile': 'http://purl.obolibrary.org/obo/ECTO_0001519',
#  'exposure to 2,6-dichlorobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001242',
#  'exposure to 2,6-dimethylaniline': 'http://purl.obolibrary.org/obo/ECTO_0001943',
#  'exposure to 2,6-dimethylnaphthalene': 'http://purl.obolibrary.org/obo/ECTO_0001243',
#  'exposure to 2,6-dinitrotoluene': 'http://purl.obolibrary.org/obo/ECTO_0001735',
#  'exposure to 2-Aminoanthraquinone': 'http://purl.obolibrary.org/obo/ECTO_0001609',
#  'exposure to 2-Methyl-4-heptanone': 'http://purl.obolibrary.org/obo/ECTO_0002333',
#  'exposure to 2-Methylaziridine': 'http://purl.obolibrary.org/obo/ECTO_0001881',
#  'exposure to 2-O-acetyl-1-O-hexadecyl-sn-glycero-3-phosphocholine': 'http://purl.obolibrary.org/obo/ECTO_0000432',
#  'exposure to 2-acetamidofluorene': 'http://purl.obolibrary.org/obo/ECTO_0001598',
#  'exposure to 2-bromophenyl 2,4-dibromophenyl ether': 'http://purl.obolibrary.org/obo/ECTO_0002416',
#  'exposure to 2-butoxyethanol': 'http://purl.obolibrary.org/obo/ECTO_0002321',
#  'exposure to 2-chloroethanol': 'http://purl.obolibrary.org/obo/ECTO_0002151',
#  'exposure to 2-chloroethyl group': 'http://purl.obolibrary.org/obo/ECTO_0001826',
#  'exposure to 2-cis-abscisic acid': 'http://purl.obolibrary.org/obo/ECTO_0000124',
#  'exposure to 2-diethylaminoethanol': 'http://purl.obolibrary.org/obo/ECTO_0002133',
#  'exposure to 2-ethoxyethanol': 'http://purl.obolibrary.org/obo/ECTO_0001745',
#  'exposure to 2-hydroxy-2-methylpropanenitrile': 'http://purl.obolibrary.org/obo/ECTO_0001804',
#  'exposure to 2-hydroxybenzothiazole': 'http://purl.obolibrary.org/obo/ECTO_0001161',
#  'exposure to 2-methoxy-5-nitroaniline': 'http://purl.obolibrary.org/obo/ECTO_0001823',
#  'exposure to 2-methoxyethanol': 'http://purl.obolibrary.org/obo/ECTO_0001795',
#  'exposure to 2-methyl-4-chlorophenoxybutyric acid': 'http://purl.obolibrary.org/obo/ECTO_0001435',
#  'exposure to 2-methylpentane-2,4-diol': 'http://purl.obolibrary.org/obo/ECTO_0002347',
#  'exposure to 2-methylpyridine': 'http://purl.obolibrary.org/obo/ECTO_0001807',
#  'exposure to 2-naphthylamine': 'http://purl.obolibrary.org/obo/ECTO_0001816',
#  'exposure to 2-nitroanisole': 'http://purl.obolibrary.org/obo/ECTO_0001822',
#  'exposure to 2-nitronaphthalene': 'http://purl.obolibrary.org/obo/ECTO_0002361',
#  'exposure to 2-nitrophenol': 'http://purl.obolibrary.org/obo/ECTO_0001828',
#  'exposure to 2-nitropropane': 'http://purl.obolibrary.org/obo/ECTO_0001830',
#  'exposure to 2-nitrotoluene': 'http://purl.obolibrary.org/obo/ECTO_0001220',
#  "exposure to 3',5'-cyclic AMP": 'http://purl.obolibrary.org/obo/ECTO_0000264',
#  "exposure to 3',5'-cyclic GMP": 'http://purl.obolibrary.org/obo/ECTO_0000271',
#  "exposure to 3,3',4,4',5-pentachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0000455',
#  "exposure to 3,3',4,4'-tetrachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001165',
#  "exposure to 3,3',5,5'-tetrabromobisphenol A": 'http://purl.obolibrary.org/obo/ECTO_0001901',
#  "exposure to 3,3',5,5'-tetrachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001264',
#  "exposure to 3,3'-Dichlorobenzidine": 'http://purl.obolibrary.org/obo/ECTO_0001704',
#  "exposure to 3,3'-Dimethoxybenzidine": 'http://purl.obolibrary.org/obo/ECTO_0001721',
#  "exposure to 3,3'-Dimethoxybenzidine-4,4'-diisocyanate": 'http://purl.obolibrary.org/obo/ECTO_0001965',
#  "exposure to 3,3'-Dimethylbenzidine": 'http://purl.obolibrary.org/obo/ECTO_0001724',
#  "exposure to 3,4,4',5-Tetrachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001416',
#  "exposure to 3,4,5,3',4',5'-Hexachlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001417',
#  'exposure to 3,5-dibromo-4-hydroxybenzonitrile': 'http://purl.obolibrary.org/obo/ECTO_0001177',
#  'exposure to 3,5-dichlorobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001246',
#  'exposure to 3-iodoprop-2-yn-1-yl butylcarbamate': 'http://purl.obolibrary.org/obo/ECTO_0001464',
#  'exposure to 3-methyl-2-butanol': 'http://purl.obolibrary.org/obo/ECTO_0002350',
#  "exposure to 3-methyl-4'-dimethylaminoazobenzene": 'http://purl.obolibrary.org/obo/ECTO_0002026',
#  'exposure to 3-methylcholanthrene': 'http://purl.obolibrary.org/obo/ECTO_0000469',
#  'exposure to 3-nitrotoluene': 'http://purl.obolibrary.org/obo/ECTO_0002217',
#  "exposure to 4'-epidoxorubicin": 'http://purl.obolibrary.org/obo/ECTO_0000387',
#  "exposure to 4,4'-Thiodianiline": 'http://purl.obolibrary.org/obo/ECTO_0001910',
#  "exposure to 4,4'-diaminodiphenylmethane": 'http://purl.obolibrary.org/obo/ECTO_0001798',
#  "exposure to 4,4'-dichlorobiphenyl": 'http://purl.obolibrary.org/obo/ECTO_0001247',
#  "exposure to 4,4'-methylene-bis-(2-chloroaniline)": 'http://purl.obolibrary.org/obo/ECTO_0002355',
#  'exposure to 4,5-dichloro-2-n-octyl-3(2H)-isothiazolone': 'http://purl.obolibrary.org/obo/ECTO_0001483',
#  'exposure to 4,6-dinitro-o-cresol': 'http://purl.obolibrary.org/obo/ECTO_0001732',
#  'exposure to 4-(phenylazo)aniline': 'http://purl.obolibrary.org/obo/ECTO_0001610',
#  'exposure to 4-Chloronitrobenzene': 'http://purl.obolibrary.org/obo/ECTO_0002360',
#  'exposure to 4-Heptanone': 'http://purl.obolibrary.org/obo/ECTO_0002337',
#  'exposure to 4-Methyl-3-penten-2-one, 9CI': 'http://purl.obolibrary.org/obo/ECTO_0002352',
#  'exposure to 4-Nitrobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001824',
#  'exposure to 4-Nitropyrene': 'http://purl.obolibrary.org/obo/ECTO_0001964',
#  'exposure to 4-aminobenzenesulfonic acid': 'http://purl.obolibrary.org/obo/ECTO_0001190',
#  'exposure to 4-bromophenyl 2,4-dibromophenyl ether': 'http://purl.obolibrary.org/obo/ECTO_0002419',
#  'exposure to 4-chloroaniline': 'http://purl.obolibrary.org/obo/ECTO_0001661',
#  'exposure to 4-chlorophenol': 'http://purl.obolibrary.org/obo/ECTO_0001707',
#  'exposure to 4-hydroxy-3-(3-oxo-1-phenylbutyl)-1-benzopyran-2-one': 'http://purl.obolibrary.org/obo/ECTO_0002274',
#  'exposure to 4-methyl-2-oxopentanoic acid': 'http://purl.obolibrary.org/obo/ECTO_0002009',
#  'exposure to 4-nitroaniline': 'http://purl.obolibrary.org/obo/ECTO_0001821',
#  'exposure to 4-nitrophenol': 'http://purl.obolibrary.org/obo/ECTO_0001829',
#  'exposure to 4-nitroquinoline N-oxide': 'http://purl.obolibrary.org/obo/ECTO_0000299',
#  'exposure to 4-nitrotoluene': 'http://purl.obolibrary.org/obo/ECTO_0002363',
#  'exposure to 4-nonylphenol': 'http://purl.obolibrary.org/obo/ECTO_0001248',
#  'exposure to 4-octylphenol': 'http://purl.obolibrary.org/obo/ECTO_0001999',
#  'exposure to 4-vinylcyclohexene dioxide': 'http://purl.obolibrary.org/obo/ECTO_0002385',
#  'exposure to 5-Methyl-2-hexanone': 'http://purl.obolibrary.org/obo/ECTO_0002357',
#  'exposure to 5-Methylchrysene': 'http://purl.obolibrary.org/obo/ECTO_0001961',
#  "exposure to 5-bromo-2'-deoxyuridine": 'http://purl.obolibrary.org/obo/ECTO_0002008',
#  "exposure to 5-fluoro-2'-deoxyuridine": 'http://purl.obolibrary.org/obo/ECTO_0000318',
#  'exposure to 5-fluorouracil': 'http://purl.obolibrary.org/obo/ECTO_0000226',
#  'exposure to 5-methyl-1H-benzotriazole': 'http://purl.obolibrary.org/obo/ECTO_0001466',
#  'exposure to 5-nitro-o-toluidine': 'http://purl.obolibrary.org/obo/ECTO_0001839',
#  'exposure to 6-Nitrochrysene': 'http://purl.obolibrary.org/obo/ECTO_0001962',
#  'exposure to 6-phenyl-2,3,5,6-tetrahydroimidazo[2,1-b][1,3]thiazole': 'http://purl.obolibrary.org/obo/ECTO_0001405',
#  'exposure to 6:2 fluorotelomer unsaturated carboxylic acid': 'http://purl.obolibrary.org/obo/ECTO_0001471',
#  'exposure to 6alpha-methylprednisolone': 'http://purl.obolibrary.org/obo/ECTO_0001389',
#  'exposure to 7,12-dimethyltetraphene': 'http://purl.obolibrary.org/obo/ECTO_0001987',
#  'exposure to 8:2 fluorotelomer unsaturated carboxylic acid': 'http://purl.obolibrary.org/obo/ECTO_0001472',
#  'exposure to ANTU': 'http://purl.obolibrary.org/obo/ECTO_0002318',
#  'exposure to AP-1 antagonist': 'http://purl.obolibrary.org/obo/ECTO_0000838',
#  'exposure to ATP': 'http://purl.obolibrary.org/obo/ECTO_0000190',
#  'exposure to Allyl chloride': 'http://purl.obolibrary.org/obo/ECTO_0001605',
#  'exposure to Ammonium sulfamate': 'http://purl.obolibrary.org/obo/ECTO_0002316',
#  'exposure to Aroclor 1254': 'http://purl.obolibrary.org/obo/ECTO_0000421',
#  'exposure to Arsenobetaine': 'http://purl.obolibrary.org/obo/ECTO_0001560',
#  'exposure to Aurora kinase inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000849',
#  'exposure to B vitamin': 'http://purl.obolibrary.org/obo/ECTO_0000880',
#  'exposure to Benzal chloride': 'http://purl.obolibrary.org/obo/ECTO_0001621',
#  'exposure to Benzotrichloride': 'http://purl.obolibrary.org/obo/ECTO_0001624',
#  'exposure to Benzoyl chloride': 'http://purl.obolibrary.org/obo/ECTO_0001625',
#  'exposure to Benzoyl peroxide': 'http://purl.obolibrary.org/obo/ECTO_0001626',
#  'exposure to Bis(2-chloro-1-methylethyl)ether': 'http://purl.obolibrary.org/obo/ECTO_0001632',
#  'exposure to Bis(2-chloroethyl)ether': 'http://purl.obolibrary.org/obo/ECTO_0002328',
#  'exposure to Bis(chloromethyl) ether': 'http://purl.obolibrary.org/obo/ECTO_0001631',
#  'exposure to Bronsted acid': 'http://purl.obolibrary.org/obo/ECTO_0000650',
#  'exposure to Brucine': 'http://purl.obolibrary.org/obo/ECTO_0001638',
#  'exposure to CCCP': 'http://purl.obolibrary.org/obo/ECTO_0000300',
#  'exposure to Chloramben': 'http://purl.obolibrary.org/obo/ECTO_0001654',
#  'exposure to Chloroacetyl chloride': 'http://purl.obolibrary.org/obo/ECTO_0002324',
#  'exposure to Chlorobenzilate': 'http://purl.obolibrary.org/obo/ECTO_0001662',
#  'exposure to Chlorodifluoromethane': 'http://purl.obolibrary.org/obo/ECTO_0001663',
#  'exposure to Chloromethyl methyl ether': 'http://purl.obolibrary.org/obo/ECTO_0001667',
#  'exposure to Crufomate': 'http://purl.obolibrary.org/obo/ECTO_0002326',
#  'exposure to Cycloate': 'http://purl.obolibrary.org/obo/ECTO_0001686',
#  'exposure to D-galactosamine': 'http://purl.obolibrary.org/obo/ECTO_0000440',
#  'exposure to DDE': 'http://purl.obolibrary.org/obo/ECTO_0001172',
#  'exposure to DDT': 'http://purl.obolibrary.org/obo/ECTO_0000247',
#  'exposure to DDT in air': 'http://purl.obolibrary.org/obo/ECTO_0000968',
#  'exposure to DDT in soil': 'http://purl.obolibrary.org/obo/ECTO_0000969',
#  'exposure to DDT in water': 'http://purl.obolibrary.org/obo/ECTO_0000970',
#  'exposure to DNA synthesis inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000752',
#  'exposure to Dalapon': 'http://purl.obolibrary.org/obo/ECTO_0002329',
#  'exposure to Decabromodiphenyl oxide': 'http://purl.obolibrary.org/obo/ECTO_0001694',
#  'exposure to Dichloroacetylene': 'http://purl.obolibrary.org/obo/ECTO_0002327',
#  'exposure to Diclofop methyl': 'http://purl.obolibrary.org/obo/ECTO_0001711',
#  'exposure to Dicyclopentadiene': 'http://purl.obolibrary.org/obo/ECTO_0001713',
#  'exposure to Diglycidyl resorcinol ether': 'http://purl.obolibrary.org/obo/ECTO_0001718',
#  'exposure to Dihydrosafrole': 'http://purl.obolibrary.org/obo/ECTO_0001719',
#  'exposure to Dimethipin': 'http://purl.obolibrary.org/obo/ECTO_0001720',
#  'exposure to Dimethyl phthalate': 'http://purl.obolibrary.org/obo/ECTO_0001727',
#  'exposure to Dimethylcarbamoyl chloride': 'http://purl.obolibrary.org/obo/ECTO_0002335',
#  'exposure to Dioxation': 'http://purl.obolibrary.org/obo/ECTO_0002336',
#  'exposure to Diphenamid': 'http://purl.obolibrary.org/obo/ECTO_0001739',
#  'exposure to EC 1.1.1.188 (prostaglandin-F synthase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000913',
#  'exposure to EC 1.1.1.189 (prostaglandin-E2 9-reductase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000908',
#  'exposure to EC 1.1.1.205 (IMP dehydrogenase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000745',
#  'exposure to EC 1.1.1.21 (aldehyde reductase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000667',
#  'exposure to EC 1.1.1.25 (shikimate dehydrogenase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000914',
#  'exposure to EC 1.1.1.267 (1-deoxy-D-xylulose-5-phosphate reductoisomerase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000916',
#  'exposure to EC 1.10.3.1 (catechol oxidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000952',
#  'exposure to EC 1.10.3.2 (laccase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000953',
#  'exposure to EC 1.10.99.2 [ribosyldihydronicotinamide dehydrogenase (quinone)] inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000904',
#  'exposure to EC 1.11.1.11 (L-ascorbate peroxidase) inhibitors': 'http://purl.obolibrary.org/obo/ECTO_0000861',
#  'exposure to EC 1.11.1.6 (catalase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000876',
#  'exposure to EC 1.13.11.24 (quercetin 2,3-dioxygenase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000954',
#  'exposure to EC 1.13.11.33 (arachidonate 15-lipoxygenase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000816',
#  'exposure to EC 1.13.11.34 (arachidonate 5-lipoxygenase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000815',
#  'exposure to EC 1.14.13.39 (nitric oxide synthase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000770',
#  'exposure to EC 1.14.18.1 (tyrosinase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000759',
#  'exposure to EC 1.14.99.1 (prostaglandin-endoperoxide synthase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000586',
#  'exposure to EC 1.17.4.1 (ribonucleoside-diphosphate reductase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000869',
#  'exposure to EC 1.2.1.12 [glyceraldehyde-3-phosphate dehydrogenase (phosphorylating)] inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000852',
#  'exposure to EC 1.2.1.3 [aldehyde dehydrogenase (NAD(+))] inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000576',
#  'exposure to EC 1.2.3.1 (aldehyde oxidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000779',
#  'exposure to EC 1.3.1.43 (arogenate dehydrogenase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000800',
#  'exposure to EC 1.4.3.3 (D-amino-acid oxidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000955',
#  'exposure to EC 1.5.1.3 (dihydrofolate reductase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000713',
#  'exposure to EC 1.6.5.2 [NAD(P)H dehydrogenase (quinone)] inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000698',
#  'exposure to EC 1.8.1.9 (thioredoxin reductase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000808',
#  'exposure to EC 1.9.3.1 (cytochrome c oxidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000637',
#  "exposure to EC 2.1.1.116 [3'-hydroxy-N-methyl-(S)-coclaurine 4'-O-methyltransferase] inhibitor": 'http://purl.obolibrary.org/obo/ECTO_0000907',
#  'exposure to EC 2.1.1.72 [site-specific DNA-methyltransferase (adenine-specific)] inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000822',
#  'exposure to EC 2.1.1.79 (cyclopropane-fatty-acyl-phospholipid synthase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000821',
#  'exposure to EC 2.1.2.1 (glycine hydroxymethyltransferase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000802',
#  'exposure to EC 2.2.1.6 (acetolactate synthase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000495',
#  'exposure to EC 2.3.1.21 (carnitine O-palmitoyltransferase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000783',
#  'exposure to EC 2.3.1.85 (fatty acid synthase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000858',
#  'exposure to EC 2.4.2.30 (NAD(+) ADP-ribosyltransferase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000780',
#  'exposure to EC 2.5.1.15 (dihydropteroate synthase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000701',
#  'exposure to EC 2.5.1.18 (glutathione transferase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000889',
#  'exposure to EC 2.5.1.19 (3-phosphoshikimate 1-carboxyvinyltransferase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000492',
#  'exposure to EC 2.5.1.29 (geranylgeranyl diphosphate synthase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000799',
#  'exposure to EC 2.5.1.58 (protein farnesyltransferase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000795',
#  'exposure to EC 2.7.1.1 (hexokinase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000933',
#  'exposure to EC 2.7.1.137 (phosphatidylinositol 3-kinase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000731',
#  'exposure to EC 2.7.10.2 (non-specific protein-tyrosine kinase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000887',
#  'exposure to EC 2.7.11.1 (non-specific serine/threonine protein kinase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000733',
#  'exposure to EC 2.7.11.13 (protein kinase C) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000615',
#  'exposure to EC 2.7.7.49 (RNA-directed DNA polymerase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000758',
#  'exposure to EC 2.7.7.7 (DNA-directed DNA polymerase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000489',
#  'exposure to EC 2.7.8.15 (UDP-N-acetylglucosamine--dolichyl-phosphate N-acetylglucosaminephosphotransferase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000796',
#  'exposure to EC 3.1.1.1 (carboxylesterase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000935',
#  'exposure to EC 3.1.1.3 (triacylglycerol lipase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000817',
#  'exposure to EC 3.1.1.7 (acetylcholinesterase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000635',
#  'exposure to EC 3.1.1.8 (cholinesterase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000616',
#  'exposure to EC 3.1.3.1 (alkaline phosphatase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000787',
#  'exposure to EC 3.1.3.11 (fructose-bisphosphatase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000819',
#  'exposure to EC 3.1.3.16 (phosphoprotein phosphatase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000612',
#  'exposure to EC 3.1.3.41 (4-nitrophenylphosphatase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000905',
#  'exposure to EC 3.1.3.48 (protein-tyrosine-phosphatase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000587',
#  'exposure to EC 3.1.4.* (phosphoric diester hydrolase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000690',
#  'exposure to EC 3.1.4.11 (phosphoinositide phospholipase C) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000809',
#  'exposure to EC 3.1.4.12 (sphingomyelin phosphodiesterase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000890',
#  'exposure to EC 3.2.1.18 (exo-alpha-sialidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000740',
#  'exposure to EC 3.4.11.14 (cytosol alanyl aminopeptidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000891',
#  'exposure to EC 3.4.14.2 (dipeptidyl-peptidase II) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000892',
#  'exposure to EC 3.4.15.1 (peptidyl-dipeptidase A) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000566',
#  'exposure to EC 3.4.19.3 (pyroglutamyl-peptidase I) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000918',
#  'exposure to EC 3.4.21.26 (prolyl oligopeptidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000888',
#  'exposure to EC 3.4.21.5 (thrombin) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000825',
#  'exposure to EC 3.4.22.38 (cathepsin K) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000798',
#  'exposure to EC 3.4.24.3 (microbial collagenase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000835',
#  'exposure to EC 3.4.24.83 (anthrax lethal factor endopeptidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000911',
#  'exposure to EC 3.5.1.19 (nicotinamidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000949',
#  'exposure to EC 3.5.1.4 (amidase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000922',
#  'exposure to EC 3.5.1.98 (histone deacetylase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000769',
#  'exposure to EC 3.5.2.6 (beta-lactamase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000592',
#  'exposure to EC 3.6.3.8 (Ca(2+)-transporting ATPase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000760',
#  'exposure to EC 4.1.1.19 (arginine decarboxylase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000818',
#  'exposure to EC 4.2.1.1 (carbonic anhydrase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000502',
#  'exposure to EC 4.3.1.15 (diaminopropionate ammonia-lyase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000921',
#  'exposure to EC 4.3.1.3 (histidine ammonia-lyase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000917',
#  'exposure to EC 5.4.3.2 (lysine 2,3-aminomutase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000874',
#  'exposure to EC 5.99.1.2 (DNA topoisomerase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000696',
#  'exposure to EC 5.99.1.3 [DNA topoisomerase (ATP-hydrolysing)] inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000718',
#  'exposure to EC 6.3.1.2 (glutamate--ammonia ligase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000514',
#  'exposure to EC 6.4.1.1 (pyruvate carboxylase) inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000962',
#  'exposure to EPN': 'http://purl.obolibrary.org/obo/ECTO_0002339',
#  'exposure to EPTC': 'http://purl.obolibrary.org/obo/ECTO_0001747',
#  'exposure to Enterodiol': 'http://purl.obolibrary.org/obo/ECTO_0001556',
#  'exposure to Enterolactone': 'http://purl.obolibrary.org/obo/ECTO_0001557',
#  'exposure to Enterovirus infection': 'http://purl.obolibrary.org/obo/ECTO_0002300',
#  'exposure to Ethyl acrylate': 'http://purl.obolibrary.org/obo/ECTO_0001746',
#  'exposure to Ethylenethiourea': 'http://purl.obolibrary.org/obo/ECTO_0002341',
#  'exposure to Fenchlorphos': 'http://purl.obolibrary.org/obo/ECTO_0002372',
#  'exposure to Fenoxaprop ethyl': 'http://purl.obolibrary.org/obo/ECTO_0001754',
#  'exposure to Fluazifop butyl': 'http://purl.obolibrary.org/obo/ECTO_0001759',
#  'exposure to Fluometuron': 'http://purl.obolibrary.org/obo/ECTO_0001760',
#  'exposure to Fomesafen': 'http://purl.obolibrary.org/obo/ECTO_0001764',
#  'exposure to G-protein-coupled receptor agonist': 'http://purl.obolibrary.org/obo/ECTO_0000854',
#  'exposure to GABA antagonist': 'http://purl.obolibrary.org/obo/ECTO_0000827',
#  'exposure to GABA modulator': 'http://purl.obolibrary.org/obo/ECTO_0000695',
#  'exposure to GABA-gated chloride channel antagonist': 'http://purl.obolibrary.org/obo/ECTO_0000649',
#  'exposure to GHB receptor agonist': 'http://purl.obolibrary.org/obo/ECTO_0000744',
#  'exposure to GW 7647': 'http://purl.obolibrary.org/obo/ECTO_0000363',
#  'exposure to Guinea Green B': 'http://purl.obolibrary.org/obo/ECTO_0001672',
#  'exposure to H1-receptor antagonist': 'http://purl.obolibrary.org/obo/ECTO_0000621',
#  'exposure to Helicobacter pylori infection': 'http://purl.obolibrary.org/obo/ECTO_0002301',
#  'exposure to Heptachlor epoxide': 'http://purl.obolibrary.org/obo/ECTO_0001528',
#  'exposure to Hexachloro-1,3-butadiene': 'http://purl.obolibrary.org/obo/ECTO_0001767',
#  'exposure to Hexazinone': 'http://purl.obolibrary.org/obo/ECTO_0001770',
#  'exposure to Hsp90 inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000791',
#  'exposure to Isodrin': 'http://purl.obolibrary.org/obo/ECTO_0001780',
#  'exposure to Isosafrole': 'http://purl.obolibrary.org/obo/ECTO_0001783',
#  'exposure to L-arginine': 'http://purl.obolibrary.org/obo/ECTO_0000410',
#  'exposure to L-ascorbic acid': 'http://purl.obolibrary.org/obo/ECTO_0000195',
#  'exposure to L-canavanine': 'http://purl.obolibrary.org/obo/ECTO_0000335',
#  'exposure to L-cysteine': 'http://purl.obolibrary.org/obo/ECTO_0000337',
#  'exposure to L-dopa': 'http://purl.obolibrary.org/obo/ECTO_0000441',
#  'exposure to L-glutamate(2-)': 'http://purl.obolibrary.org/obo/ECTO_0000374',
#  'exposure to L-glutamine': 'http://purl.obolibrary.org/obo/ECTO_0000473',
#  'exposure to L-lysine': 'http://purl.obolibrary.org/obo/ECTO_0001955',
#  'exposure to L-phenylalanine derivative': 'http://purl.obolibrary.org/obo/ECTO_0000436',
#  'exposure to L-thialysine': 'http://purl.obolibrary.org/obo/ECTO_0000334',
#  'exposure to L-thyroxine': 'http://purl.obolibrary.org/obo/ECTO_0000312',
#  'exposure to MALDI matrix material': 'http://purl.obolibrary.org/obo/ECTO_0000797',
#  'exposure to MRI contrast agent': 'http://purl.obolibrary.org/obo/ECTO_0000613',
#  'exposure to Maillard reaction product': 'http://purl.obolibrary.org/obo/ECTO_0000915',
#  'exposure to Methazole': 'http://purl.obolibrary.org/obo/ECTO_0001793',
#  'exposure to Methyl acrylate': 'http://purl.obolibrary.org/obo/ECTO_0001796',
#  'exposure to Methyl isobutyl ketone': 'http://purl.obolibrary.org/obo/ECTO_0001801',
#  'exposure to Molinate': 'http://purl.obolibrary.org/obo/ECTO_0001810',
#  'exposure to N,N-diethyl-m-toluamide': 'http://purl.obolibrary.org/obo/ECTO_0001394',
#  'exposure to N,N-dimethylacetamide': 'http://purl.obolibrary.org/obo/ECTO_0002334',
#  'exposure to N,N-dimethylaniline': 'http://purl.obolibrary.org/obo/ECTO_0001723',
#  'exposure to N,N-dimethylformamide': 'http://purl.obolibrary.org/obo/ECTO_0001725',
#  'exposure to N-Methylolacrylamide': 'http://purl.obolibrary.org/obo/ECTO_0001806',
#  'exposure to N-Nitrosodi-n-butylamine': 'http://purl.obolibrary.org/obo/ECTO_0001831',
#  'exposure to N-Nitrosodi-n-propylamine': 'http://purl.obolibrary.org/obo/ECTO_0001835',
#  'exposure to N-Nitrosodiphenylamine': 'http://purl.obolibrary.org/obo/ECTO_0001834',
#  'exposure to N-Nitrosomethylvinylamine': 'http://purl.obolibrary.org/obo/ECTO_0001837',
#  'exposure to N-Phenyl-2-naphthylamine': 'http://purl.obolibrary.org/obo/ECTO_0002365',
#  'exposure to N-acetyl-D-glucosamine': 'http://purl.obolibrary.org/obo/ECTO_0000316',
#  'exposure to N-ethyl-N-nitrosourea': 'http://purl.obolibrary.org/obo/ECTO_0001986',
#  'exposure to N-ethylperfluorooctane sulfonamidoacetic acid': 'http://purl.obolibrary.org/obo/ECTO_0001480',
#  "exposure to N-methyl-N'-nitro-N-nitrosoguanidine": 'http://purl.obolibrary.org/obo/ECTO_0001984',
#  'exposure to N-methyl-N-nitrosourea': 'http://purl.obolibrary.org/obo/ECTO_0001836',
#  'exposure to N-methyl-N-picrylnitramine': 'http://purl.obolibrary.org/obo/ECTO_0002380',
#  'exposure to N-methylaniline': 'http://purl.obolibrary.org/obo/ECTO_0002359',
#  'exposure to N-methylperfluorooctane sulfonamidoacetic acid': 'http://purl.obolibrary.org/obo/ECTO_0001479',
#  'exposure to N-nitrosodiethylamine': 'http://purl.obolibrary.org/obo/ECTO_0001832',
#  'exposure to N-nitrosodimethylamine': 'http://purl.obolibrary.org/obo/ECTO_0001833',
#  'exposure to N-nitrosomorpholine': 'http://purl.obolibrary.org/obo/ECTO_0001838',
#  'exposure to N-nitrosopiperidine': 'http://purl.obolibrary.org/obo/ECTO_0001404',
#  'exposure to N-phenylthiourea': 'http://purl.obolibrary.org/obo/ECTO_0000388',
#  'exposure to NF-kappaB inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000864',
#  'exposure to NMDA receptor agonist': 'http://purl.obolibrary.org/obo/ECTO_0000803',
#  'exposure to NMDA receptor antagonist': 'http://purl.obolibrary.org/obo/ECTO_0000763',
#  'exposure to Nitrapyrin': 'http://purl.obolibrary.org/obo/ECTO_0001818',
#  'exposure to Nitrofen': 'http://purl.obolibrary.org/obo/ECTO_0001825',
#  'exposure to Nonylphenol': 'http://purl.obolibrary.org/obo/ECTO_0000427',
#  'exposure to O-Desmethylangolensin': 'http://purl.obolibrary.org/obo/ECTO_0001559',
#  'exposure to O-methyleugenol': 'http://purl.obolibrary.org/obo/ECTO_0001799',
#  'exposure to Octachlorostyrene': 'http://purl.obolibrary.org/obo/ECTO_0001841',
#  'exposure to Oxyfluorfen': 'http://purl.obolibrary.org/obo/ECTO_0001845',
#  'exposure to P2Y12 receptor antagonist': 'http://purl.obolibrary.org/obo/ECTO_0000844',
#  'exposure to P450 inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000689',
#  'exposure to PPARalpha agonist': 'http://purl.obolibrary.org/obo/ECTO_0000851',
#  'exposure to Papillomaviridae infection': 'http://purl.obolibrary.org/obo/ECTO_0002302',
#  'exposure to Pebulate': 'http://purl.obolibrary.org/obo/ECTO_0001849',
#  'exposure to Pentobarbital sodium': 'http://purl.obolibrary.org/obo/ECTO_0001853',
#  'exposure to Phenyl glycidyl ether': 'http://purl.obolibrary.org/obo/ECTO_0002364',
#  'exposure to Picloram': 'http://purl.obolibrary.org/obo/ECTO_0001866',
#  'exposure to Pindone': 'http://purl.obolibrary.org/obo/ECTO_0002368',
#  'exposure to Pronamide': 'http://purl.obolibrary.org/obo/ECTO_0001872',
#  'exposure to Quizalofop-ethyl': 'http://purl.obolibrary.org/obo/ECTO_0001886',
#  'exposure to Ricin': 'http://purl.obolibrary.org/obo/ECTO_0002289',
#  'exposure to Sethoxydim': 'http://purl.obolibrary.org/obo/ECTO_0001889',
#  'exposure to Sir2 inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000855',
#  'exposure to Sirius red 4B': 'http://purl.obolibrary.org/obo/ECTO_0001510',
#  'exposure to Soman': 'http://purl.obolibrary.org/obo/ECTO_0002388',
#  'exposure to Sudan I': 'http://purl.obolibrary.org/obo/ECTO_0001675',
#  'exposure to Sudan II': 'http://purl.obolibrary.org/obo/ECTO_0001673',
#  'exposure to T-cell proliferation inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000784',
#  'exposure to TEPP': 'http://purl.obolibrary.org/obo/ECTO_0002377',
#  'exposure to Terbacil': 'http://purl.obolibrary.org/obo/ECTO_0001900',
#  'exposure to Tetracycline hydrochloride': 'http://purl.obolibrary.org/obo/ECTO_0001904',
#  'exposure to Tetranitromethane': 'http://purl.obolibrary.org/obo/ECTO_0001906',
#  'exposure to Thiobencarb': 'http://purl.obolibrary.org/obo/ECTO_0001909',
#  'exposure to Thyroglobulin triiodothyronine': 'http://purl.obolibrary.org/obo/ECTO_0000423',
#  'exposure to Thyroid stimulating hormone': 'http://purl.obolibrary.org/obo/ECTO_0000437',
#  'exposure to Tri-allate': 'http://purl.obolibrary.org/obo/ECTO_0001918',
#  'exposure to Tris(2,3-dibromopropyl) phosphate': 'http://purl.obolibrary.org/obo/ECTO_0001933',
#  'exposure to Vat Yellow 4': 'http://purl.obolibrary.org/obo/ECTO_0001677',
#  'exposure to Vinylidene fluoride': 'http://purl.obolibrary.org/obo/ECTO_0002386',
#  'exposure to Viruses infection': 'http://purl.obolibrary.org/obo/ECTO_0002299',
#  'exposure to abamectin': 'http://purl.obolibrary.org/obo/ECTO_0001592',
#  'exposure to abortifacient': 'http://purl.obolibrary.org/obo/ECTO_0000715',
#  'exposure to abscisic acid receptor agonist': 'http://purl.obolibrary.org/obo/ECTO_0000863',
#  'exposure to acadesine': 'http://purl.obolibrary.org/obo/ECTO_0000425',
#  'exposure to acamprosate': 'http://purl.obolibrary.org/obo/ECTO_0001353',
#  'exposure to acaricide': 'http://purl.obolibrary.org/obo/ECTO_0000494',
#  'exposure to acaricide drug': 'http://purl.obolibrary.org/obo/ECTO_0001029',
#  'exposure to accumulation of toxins from algal bloom process': 'http://purl.obolibrary.org/obo/ECTO_0000097',
#  'exposure to acephate': 'http://purl.obolibrary.org/obo/ECTO_0001593',
#  'exposure to acepromazine': 'http://purl.obolibrary.org/obo/ECTO_0002006',
#  'exposure to acesulfame': 'http://purl.obolibrary.org/obo/ECTO_0001475',
#  'exposure to acetaldehyde': 'http://purl.obolibrary.org/obo/ECTO_0001594',
#  'exposure to acetamide': 'http://purl.obolibrary.org/obo/ECTO_0001595',
#  'exposure to acetamiprid': 'http://purl.obolibrary.org/obo/ECTO_0001298',
#  'exposure to acetate': 'http://purl.obolibrary.org/obo/ECTO_0000136',
#  'exposure to acetic acid': 'http://purl.obolibrary.org/obo/ECTO_0002063',
#  'exposure to acetic anhydride': 'http://purl.obolibrary.org/obo/ECTO_0002064',
#  'exposure to acetochlor': 'http://purl.obolibrary.org/obo/ECTO_0001181',
#  'exposure to acetone': 'http://purl.obolibrary.org/obo/ECTO_0002065',
#  'exposure to acetonitrile': 'http://purl.obolibrary.org/obo/ECTO_0001596',
#  'exposure to acetophenone': 'http://purl.obolibrary.org/obo/ECTO_0001597',
#  'exposure to acetylcholine': 'http://purl.obolibrary.org/obo/ECTO_0000479',
#  'exposure to acetylene': 'http://purl.obolibrary.org/obo/ECTO_0002068',
#  'exposure to acetylsalicylate': 'http://purl.obolibrary.org/obo/ECTO_0000405',
#  'exposure to acetylsalicylic acid': 'http://purl.obolibrary.org/obo/ECTO_0002069',
#  'exposure to acid red 4': 'http://purl.obolibrary.org/obo/ECTO_0001504',
#  'exposure to acidification of an aquatic environment': 'http://purl.obolibrary.org/obo/ECTO_0000072',
#  'exposure to acrolein': 'http://purl.obolibrary.org/obo/ECTO_0001599',
#  'exposure to acrylamide': 'http://purl.obolibrary.org/obo/ECTO_0000417',
#  'exposure to acrylic acid': 'http://purl.obolibrary.org/obo/ECTO_0001600',
#  'exposure to acrylonitrile': 'http://purl.obolibrary.org/obo/ECTO_0001601',
#  'exposure to actin polymerisation inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000848',
#  'exposure to actinomycin D': 'http://purl.obolibrary.org/obo/ECTO_0000295',
#  'exposure to acyl donor': 'http://purl.obolibrary.org/obo/ECTO_0000774',
#  'exposure to adenosine A1 receptor agonist': 'http://purl.obolibrary.org/obo/ECTO_0000820',
#  'exposure to adenosine A2A receptor antagonist': 'http://purl.obolibrary.org/obo/ECTO_0000743',
#  'exposure to adenosine A3 receptor antagonist': 'http://purl.obolibrary.org/obo/ECTO_0000847',
# ...
#  'exposure to tetracycline': 'http://purl.obolibrary.org/obo/ECTO_0000330',
#  'exposure to tetraethyllead': 'http://purl.obolibrary.org/obo/ECTO_0002260',
#  'exposure to tetrafluoroethene': 'http://purl.obolibrary.org/obo/ECTO_0001905',
#  'exposure to tetrahydrofolate': 'http://purl.obolibrary.org/obo/ECTO_0000442',
#  'exposure to tetralin': 'http://purl.obolibrary.org/obo/ECTO_0000347',
#  'exposure to tetramethrin': 'http://purl.obolibrary.org/obo/ECTO_0001907',
#  'exposure to tetramethyllead': 'http://purl.obolibrary.org/obo/ECTO_0002378',
#  'exposure to tetrazine acaricide': 'http://purl.obolibrary.org/obo/ECTO_0001042',
#  'exposure to thallium': 'http://purl.obolibrary.org/obo/ECTO_0001530',
#  'exposure to thallium molecular entity': 'http://purl.obolibrary.org/obo/ECTO_0001950',
#  'exposure to thapsigargin': 'http://purl.obolibrary.org/obo/ECTO_0000450',
#  'exposure to thiabendazole': 'http://purl.obolibrary.org/obo/ECTO_0000294',
#  'exposure to thiacloprid': 'http://purl.obolibrary.org/obo/ECTO_0001303',
#  'exposure to thiamethoxam': 'http://purl.obolibrary.org/obo/ECTO_0001307',
#  'exposure to thiamine(1+)': 'http://purl.obolibrary.org/obo/ECTO_0000156',
#  'exposure to thifensulfuron-methyl': 'http://purl.obolibrary.org/obo/ECTO_0001465',
#  'exposure to thioacetamide': 'http://purl.obolibrary.org/obo/ECTO_0001908',
#  'exposure to thiocyanate': 'http://purl.obolibrary.org/obo/ECTO_0001147',
#  'exposure to thiodicarb': 'http://purl.obolibrary.org/obo/ECTO_0001911',
#  'exposure to thioglycolic acid': 'http://purl.obolibrary.org/obo/ECTO_0002262',
#  'exposure to thionyl dichloride': 'http://purl.obolibrary.org/obo/ECTO_0002263',
#  'exposure to thiopental': 'http://purl.obolibrary.org/obo/ECTO_0001157',
#  'exposure to thiophenol': 'http://purl.obolibrary.org/obo/ECTO_0002078',
#  'exposure to thiourea': 'http://purl.obolibrary.org/obo/ECTO_0001912',
#  'exposure to thiram': 'http://purl.obolibrary.org/obo/ECTO_0001913',
#  'exposure to thorium dioxide': 'http://purl.obolibrary.org/obo/ECTO_0001914',
#  'exposure to thyroid hormone': 'http://purl.obolibrary.org/obo/ECTO_0000761',
#  'exposure to tin': 'http://purl.obolibrary.org/obo/ECTO_0001576',
#  'exposure to tin dioxide': 'http://purl.obolibrary.org/obo/ECTO_0002264',
#  'exposure to titanium dioxide': 'http://purl.obolibrary.org/obo/ECTO_0002265',
#  'exposure to titanium dioxide nanoparticle': 'http://purl.obolibrary.org/obo/ECTO_0002014',
#  'exposure to tocolytic agent': 'http://purl.obolibrary.org/obo/ECTO_0000831',
#  'exposure to toluene': 'http://purl.obolibrary.org/obo/ECTO_0000341',
#  'exposure to toluene 2,4-diisocyanate': 'http://purl.obolibrary.org/obo/ECTO_0002298',
#  'exposure to toluene meta-diisocyanate': 'http://purl.obolibrary.org/obo/ECTO_0001915',
#  'exposure to toxaphene': 'http://purl.obolibrary.org/obo/ECTO_0001408',
#  'exposure to toxin': 'http://purl.obolibrary.org/obo/ECTO_0000537',
#  'exposure to tracer': 'http://purl.obolibrary.org/obo/ECTO_0000554',
#  'exposure to tramadol': 'http://purl.obolibrary.org/obo/ECTO_0001521',
#  'exposure to trans-1,2-dichloroethene': 'http://purl.obolibrary.org/obo/ECTO_0001542',
#  'exposure to trans-1,4-Dichlorobutene': 'http://purl.obolibrary.org/obo/ECTO_0001705',
#  'exposure to trans-chlordane': 'http://purl.obolibrary.org/obo/ECTO_0001296',
#  'exposure to transition element': 'http://purl.obolibrary.org/obo/ECTO_0000481',
#  'exposure to trehalose': 'http://purl.obolibrary.org/obo/ECTO_0000160',
#  'exposure to triadimefon': 'http://purl.obolibrary.org/obo/ECTO_0001917',
#  'exposure to triazine insecticide': 'http://purl.obolibrary.org/obo/ECTO_0000625',
#  'exposure to triaziquone': 'http://purl.obolibrary.org/obo/ECTO_0001919',
#  'exposure to tribenuron methyl': 'http://purl.obolibrary.org/obo/ECTO_0001920',
#  'exposure to tribufos': 'http://purl.obolibrary.org/obo/ECTO_0001921',
#  'exposure to tributyl phosphate': 'http://purl.obolibrary.org/obo/ECTO_0002266',
#  'exposure to tributylstannane': 'http://purl.obolibrary.org/obo/ECTO_0001633',
#  'exposure to trichlopyr': 'http://purl.obolibrary.org/obo/ECTO_0001522',
#  'exposure to trichlorfon': 'http://purl.obolibrary.org/obo/ECTO_0001922',
#  'exposure to trichloroacetic acid': 'http://purl.obolibrary.org/obo/ECTO_0002382',
#  'exposure to trichlorobiphenyl': 'http://purl.obolibrary.org/obo/ECTO_0001270',
#  'exposure to trichloroethene': 'http://purl.obolibrary.org/obo/ECTO_0001145',
#  'exposure to trichlorofluoromethane': 'http://purl.obolibrary.org/obo/ECTO_0001341',
#  'exposure to trichodermin': 'http://purl.obolibrary.org/obo/ECTO_0000328',
#  'exposure to trichostatin A': 'http://purl.obolibrary.org/obo/ECTO_0000219',
#  'exposure to triclocarban': 'http://purl.obolibrary.org/obo/ECTO_0001342',
#  'exposure to triclosan': 'http://purl.obolibrary.org/obo/ECTO_0002059',
#  'exposure to triethylamine': 'http://purl.obolibrary.org/obo/ECTO_0001927',
#  'exposure to trifluorochlorine': 'http://purl.obolibrary.org/obo/ECTO_0002103',
#  'exposure to trifluoromethyl group': 'http://purl.obolibrary.org/obo/ECTO_0001784',
#  'exposure to trifluralin': 'http://purl.obolibrary.org/obo/ECTO_0001262',
#  'exposure to triforine': 'http://purl.obolibrary.org/obo/ECTO_0001928',
#  'exposure to triglyceride': 'http://purl.obolibrary.org/obo/ECTO_0000201',
#  'exposure to trimethaphan camsylate': 'http://purl.obolibrary.org/obo/ECTO_0002031',
#  'exposure to trimethoprim': 'http://purl.obolibrary.org/obo/ECTO_0001328',
#  'exposure to trimethylamine': 'http://purl.obolibrary.org/obo/ECTO_0002268',
#  'exposure to trimethylarsine oxide': 'http://purl.obolibrary.org/obo/ECTO_0002425',
#  'exposure to trimipramine': 'http://purl.obolibrary.org/obo/ECTO_0001523',
#  'exposure to trinexapac-ethyl': 'http://purl.obolibrary.org/obo/ECTO_0001436',
#  'exposure to triphenyl phosphate': 'http://purl.obolibrary.org/obo/ECTO_0002271',
#  'exposure to triphenylmethane': 'http://purl.obolibrary.org/obo/ECTO_0001403',
#  'exposure to tris(2-butoxyethyl) phosphate': 'http://purl.obolibrary.org/obo/ECTO_0001263',
#  'exposure to trisodium hexafluoroaluminate': 'http://purl.obolibrary.org/obo/ECTO_0002250',
#  'exposure to tritosulfuron': 'http://purl.obolibrary.org/obo/ECTO_0001474',
#  'exposure to tropane': 'http://purl.obolibrary.org/obo/ECTO_0000166',
#  'exposure to trypan blue': 'http://purl.obolibrary.org/obo/ECTO_0001934',
#  'exposure to trypanocidal drug': 'http://purl.obolibrary.org/obo/ECTO_0000611',
#  'exposure to tsunami': 'http://purl.obolibrary.org/obo/ECTO_0000075',
#  'exposure to tubulin modulator': 'http://purl.obolibrary.org/obo/ECTO_0000766',
#  'exposure to tungsten': 'http://purl.obolibrary.org/obo/ECTO_0001577',
#  'exposure to tunicamycin': 'http://purl.obolibrary.org/obo/ECTO_0000449',
#  'exposure to tylosin': 'http://purl.obolibrary.org/obo/ECTO_0001178',
#  'exposure to tyrosine kinase inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0000639',
#  'exposure to ultrafine respirable suspended particulate matter': 'http://purl.obolibrary.org/obo/ECTO_0000114',
#  'exposure to ultrafine respirable suspended particulate matter via inhalation': 'http://purl.obolibrary.org/obo/ECTO_0000977',
#  'exposure to ultrasound radiation': 'http://purl.obolibrary.org/obo/ECTO_0000014',
#  'exposure to ultraviolet filter': 'http://purl.obolibrary.org/obo/ECTO_0000866',
#  'exposure to ultraviolet radiation': 'http://purl.obolibrary.org/obo/ECTO_0000006',
#  'exposure to undecane': 'http://purl.obolibrary.org/obo/ECTO_0000395',
#  'exposure to uranium': 'http://purl.obolibrary.org/obo/ECTO_0001531',
#  'exposure to urban flooding': 'http://purl.obolibrary.org/obo/ECTO_0000094',
#  'exposure to urban pollution': 'http://purl.obolibrary.org/obo/ECTO_0000107',
#  'exposure to uremic toxin': 'http://purl.obolibrary.org/obo/ECTO_0000805',
#  'exposure to urethane': 'http://purl.obolibrary.org/obo/ECTO_0001935',
#  'exposure to valsartan': 'http://purl.obolibrary.org/obo/ECTO_0001524',
#  'exposure to vanadate(3-)': 'http://purl.obolibrary.org/obo/ECTO_0000382',
#  'exposure to vanadium molecular entity': 'http://purl.obolibrary.org/obo/ECTO_0001936',
#  'exposure to vasoconstrictor agent': 'http://purl.obolibrary.org/obo/ECTO_0000706',
#  'exposure to vasodilator agent': 'http://purl.obolibrary.org/obo/ECTO_0000590',
#  'exposure to vasopressin': 'http://purl.obolibrary.org/obo/ECTO_0000426',
#  'exposure to venlafaxine': 'http://purl.obolibrary.org/obo/ECTO_0001525',
#  'exposure to verapamil': 'http://purl.obolibrary.org/obo/ECTO_0001526',
#  'exposure to vinclozolin': 'http://purl.obolibrary.org/obo/ECTO_0001937',
#  'exposure to vinyl acetate': 'http://purl.obolibrary.org/obo/ECTO_0001938',
#  'exposure to virulence factor': 'http://purl.obolibrary.org/obo/ECTO_0000859',
#  'exposure to visible light radiation': 'http://purl.obolibrary.org/obo/ECTO_0000007',
#  'exposure to vitamin': 'http://purl.obolibrary.org/obo/ECTO_0000542',
#  'exposure to vitamin A': 'http://purl.obolibrary.org/obo/ECTO_0000186',
#  'exposure to vitamin B6': 'http://purl.obolibrary.org/obo/ECTO_0000208',
#  'exposure to vitamin C': 'http://purl.obolibrary.org/obo/ECTO_0000493',
#  'exposure to vitamin D': 'http://purl.obolibrary.org/obo/ECTO_0000192',
#  'exposure to vitamin E': 'http://purl.obolibrary.org/obo/ECTO_0000189',
#  'exposure to vitamin K': 'http://purl.obolibrary.org/obo/ECTO_0000183',
#  'exposure to volatile oil component': 'http://purl.obolibrary.org/obo/ECTO_0000539',
#  'exposure to volatile organic compound': 'http://purl.obolibrary.org/obo/ECTO_0002406',
#  'exposure to volcanic ash': 'http://purl.obolibrary.org/obo/ECTO_0000025',
#  'exposure to volcanic eruption': 'http://purl.obolibrary.org/obo/ECTO_0000073',
#  'exposure to vulnerary': 'http://purl.obolibrary.org/obo/ECTO_0000867',
#  'exposure to waste material': 'http://purl.obolibrary.org/obo/ECTO_0000046',
#  'exposure to waste water': 'http://purl.obolibrary.org/obo/ECTO_0000029',
#  'exposure to water': 'http://purl.obolibrary.org/obo/ECTO_0000121',
#  'exposure to water pollution': 'http://purl.obolibrary.org/obo/ECTO_0000105',
#  'exposure to water-soluble vitamin': 'http://purl.obolibrary.org/obo/ECTO_0000540',
#  'exposure to waterborne particulate matter': 'http://purl.obolibrary.org/obo/ECTO_0000111',
#  'exposure to wortmannin': 'http://purl.obolibrary.org/obo/ECTO_0000448',
#  'exposure to x-ray radiation': 'http://purl.obolibrary.org/obo/ECTO_0000005',
#  'exposure to xenobiotic': 'http://purl.obolibrary.org/obo/ECTO_0000597',
#  'exposure to xenobiotic metabolite': 'http://purl.obolibrary.org/obo/ECTO_0000883',
#  'exposure to xenoestrogen': 'http://purl.obolibrary.org/obo/ECTO_0000902',
#  'exposure to ximelagatran': 'http://purl.obolibrary.org/obo/ECTO_0000228',
#  'exposure to xylene': 'http://purl.obolibrary.org/obo/ECTO_0000350',
#  'exposure to xylene contaminated soil': 'http://purl.obolibrary.org/obo/ECTO_0000043',
#  'exposure to zinc': 'http://purl.obolibrary.org/obo/ECTO_0001578',
#  'exposure to zinc atom': 'http://purl.obolibrary.org/obo/ECTO_0001944',
#  'exposure to zinc cation': 'http://purl.obolibrary.org/obo/ECTO_0000145',
#  'exposure to zinc dichloride': 'http://purl.obolibrary.org/obo/ECTO_0002276',
#  'exposure to zinc oxide': 'http://purl.obolibrary.org/obo/ECTO_0002277',
#  'exposure to zineb': 'http://purl.obolibrary.org/obo/ECTO_0001945',
#  'exposure to ziprasidone': 'http://purl.obolibrary.org/obo/ECTO_0000324',
#  'exposure to zirconium atom': 'http://purl.obolibrary.org/obo/ECTO_0002387',
#  'exposure via injection': 'http://purl.obolibrary.org/obo/ECTO_0002284',
#  'feeding regimen related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001101',
#  'flame-broiling related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001105',
#  'food consumption related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001102',
#  'hepatectomy': 'http://purl.obolibrary.org/obo/ECTO_0002050',
#  'high vegetable diet related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001100',
#  'kidney transplant': 'http://purl.obolibrary.org/obo/ECTO_0002041',
#  'left kidney transplant': 'http://purl.obolibrary.org/obo/ECTO_0002042',
#  'lifestyle related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001078',
#  'mammography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001114',
#  'myelography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001117',
#  'occupation related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001591',
#  'ovariectomy': 'http://purl.obolibrary.org/obo/ECTO_0002048',
#  'pancreatectomy': 'http://purl.obolibrary.org/obo/ECTO_0002049',
#  'personal behavior related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001081',
#  'positron emission tomography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001112',
#  'poverty related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001127',
#  'prenatal exposure to chemical entity': 'http://purl.obolibrary.org/obo/ECTO_0001150',
#  'prenatal exposure to cocaine': 'http://purl.obolibrary.org/obo/ECTO_0001128',
#  'prenatal exposure to drug': 'http://purl.obolibrary.org/obo/ECTO_0001129',
#  'prenatal exposure to lead cation': 'http://purl.obolibrary.org/obo/ECTO_0001131',
#  'prenatal exposure to mercury cation': 'http://purl.obolibrary.org/obo/ECTO_0001132',
#  'prenatal exposure to methamphetamine hydrochloride': 'http://purl.obolibrary.org/obo/ECTO_0001135',
#  'prenatal exposure to methylmercury(1+)': 'http://purl.obolibrary.org/obo/ECTO_0001133',
#  'prenatal exposure to serotonin uptake inhibitor': 'http://purl.obolibrary.org/obo/ECTO_0001130',
#  'prenatal exposure to tobacco smoking': 'http://purl.obolibrary.org/obo/ECTO_0001134',
#  'radiography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001113',
#  'red meat consumption related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001099',
#  'right kidney transplant': 'http://purl.obolibrary.org/obo/ECTO_0002043',
#  'risk reduction related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001097',
#  'sedentary lifestyle related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001079',
#  'sex behavior related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001087',
#  'smoking behavior related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001106',
#  'smoking cessation related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001107',
#  'social circumstances related exposure': 'http://purl.obolibrary.org/obo/ECTO_0002033',
#  'social networking related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001096',
#  'socioeconomic factors related exposure': 'http://purl.obolibrary.org/obo/ECTO_0002034',
#  'substance abuse related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001093',
#  'surgical implantation of organ': 'http://purl.obolibrary.org/obo/ECTO_0002040',
#  'surgical manipulation of appendage': 'http://purl.obolibrary.org/obo/ECTO_0002037',
#  'surgical manipulation of gland': 'http://purl.obolibrary.org/obo/ECTO_0002038',
#  'surgical manipulation of kidney': 'http://purl.obolibrary.org/obo/ECTO_0002036',
#  'surgical manipulation of nerve': 'http://purl.obolibrary.org/obo/ECTO_0002035',
#  'surgical manipulation of organ': 'http://purl.obolibrary.org/obo/ECTO_0002039',
#  'surgical removal of kidney': 'http://purl.obolibrary.org/obo/ECTO_0002047',
#  'surgical removal of organ': 'http://purl.obolibrary.org/obo/ECTO_0002046',
#  'tobacco smoking related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001090',
#  'tobacco use related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001089',
#  'total body radiography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001124',
#  'ultrasound tomography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001111',
#  'unemployment related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001126',
#  'vaginography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001120',
#  'violence related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001125',
#  'water consumption related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001103',
#  'welding occupations related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001153',
#  'xeroradiography  related exposure': 'http://purl.obolibrary.org/obo/ECTO_0001115'}

# %%
from collections import defaultdict
exp_terms = defaultdict(int)
for index, term in enumerate(results):
    exp_terms[term['exposure_routeLabel']] +=1

# %%
exp_terms
# Out:
# defaultdict(int,
#             {'Transdermal patch': 19,
#              'eye contact': 4935,
#              'ingestion': 4568,
#              'inhalation': 39,
#              'inhalation administration': 5156,
#              'intramuscular injection': 19,
#              'intravenous infusion': 91,
#              'skin absorption': 5026})
